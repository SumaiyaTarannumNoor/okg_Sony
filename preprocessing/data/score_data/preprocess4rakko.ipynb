# %%
import pandas as pd

df = pd.read_csv('/home/ubuntu/reflexion/OKG/OKG/preprocessing/data/score_data/rakkokeyword_sony_online_store.csv', delimiter='\t', quotechar='"', encoding='utf-16')
df
# Out:
#                   キーワード  SEO難易度     月間検索数  検索順位   推定流入数 CPC ($)  競合性  \
# 0                ゆーチューブ      55  16600000     9  519973    0.07    -
# 1                    5£      53   2740000     3  338443    0.24    4
# 2                エクスペリア      56    301000     1  131979    0.33   90
# 3                xperia      75    246000     1  107864    0.36   69
# 4                   ps5      55    550000     2   98451     0.2   85
# ..                  ...     ...       ...   ...     ...     ...  ...
# 995              wic310      26      2400     1    1052    0.13   78
# 996   xperia premium xz      47      2400     1    1052    0.09   82
# 997               sov36      49      2400     1    1052    0.12   34
# 998           置換ショートカット      30      2400     1    1052       -    -
# 999  ソニー ノイズキャンセリングイヤホン      43      2400     1    1052    0.18  100
#
#                                                    URL
# 0    https://www.sony.jp/support/tv/net/youtube/ind...
# ...

# %%
# Rename the 'Keyword' column to 'Search_Term'
df.rename(columns={'キーワード' :'Keyword'}, inplace=True)
df.rename(columns={'推定流入数' :'Clicks'}, inplace=True)
df.rename(columns={'CPC ($)' :'CPC'}, inplace=True)
df.rename(columns={'競合性' :'Competitor Score'}, inplace=True)
df.rename(columns={'検索順位' :'Rank'}, inplace=True)
df.rename(columns={'月間検索数' :'Search Amount'}, inplace=True)
df.rename(columns={'SEO難易度' :'Traffic Diff'}, inplace=True)
# save the dataframe to a new csv file
df.to_csv('/home/ubuntu/reflexion/OKG/OKG/preprocessing/data/score_data/sony_online_store.csv', sep='\t', encoding='utf-16', index=False)
